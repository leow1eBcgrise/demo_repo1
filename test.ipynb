# %%
print("Hello git demo")
# Out:
# Hello git demo

# %%
print("2nd commit")
# Out:
# 'C:\\Users\\L_Windows\\Desktop\\git-demo'

# %%
print("3rd commit")
# Out:
# 3rd commit

# %%
print("Version 1")
